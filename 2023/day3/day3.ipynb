# %%
import numpy as np

problem = """
--- Day 3: Gear Assembly ---
The missing part wasn't the only issue - one of the gears in the engine is wrong. A gear is any * symbol that is adjacent to exactly two part numbers. Its gear ratio is the result of multiplying those two numbers together.

This time, you need to find the gear ratio of every gear and add them all up so that the engineer can figure out which gear needs to be replaced.

Consider the same engine schematic again:

In this schematic, there are two gears. The first is in the top left; it has part numbers 467 and 35, so its gear ratio is 16345. The second gear is in the lower right; its gear ratio is 451490. (The * adjacent to 617 is not a gear because it is only adjacent to one part number.) Adding up all of the gear ratios produces 467835.

What is the sum of all of the gear ratios in your engine schematic?
"""

example_input = """
467..114..
...*......
..35..633.
......#...
617*......
.....+.58.
..592.....
......755.
...$.*....
.664.598..
"""
real_input = True
# Read the rucksack contents from the file
if real_input:
    with open("adventofcode.com_2023_day_3_input.txt", "r") as infile:
        example_input = infile.read()
# replace anything not number or '*' with '.'
# example_input = "".join([x if x.isdigit() or x == '*' or x == '\n' else '.' for x in example_input])
input_content = [list(line.strip()) for line in example_input.strip().split("\n")]
# input_content = input_content[26:30]

def extract_number(content_array, pos):
    # Start at the given position
    left, right = pos[1], pos[1]

    # Scan left until a non-numeric character is found or the array boundary is hit
    while left > 0 and content_array[pos[0], left-1].isdigit():
        left -= 1

    # Scan right until a non-numeric character is found or the array boundary is hit
    while right < len(content_array[0])-1 and content_array[pos[0], right+1].isdigit():
        right += 1

    # Extract the full number as a string
    number_str = content_array[pos[0], left:right+1]

    # Convert the number to an integer and return it
    return int(''.join(number_str))


def find_parts(content_array):
    gears = []
    # Print the index of all '*'s
    gear_locations = np.where(content_array == '*')
    gear_locations = list(zip(gear_locations[0], gear_locations[1]))
    # print(gear_locations)
    # Check +/-1 each position and see if there is a number
    for pos in gear_locations:
        print(f"Checking position {pos}")
        # Check if any immediate neighbours are numbers
        parts = []
        for i in range(-1, 2):
            if pos[0] + i < 0:
                continue
            # print(f"Scanning Row {content_array[pos[0]+i, :]}")
            for j in range(-1, 2):
                if pos[1] + j < 0:
                    continue
                # print(f"Scanning column {content_array[:, pos[1]+j]}")
                # Guard against overbounds
                try:
                    if content_array[pos[0] + i, pos[1] + j].isdigit():
                        # print(f"Found a number at {pos[0] + i, pos[1] + j}, {content_array[pos[0] + i, pos[1] + j]}")
                        parts.append([pos[0] + i, pos[1] + j])
                except IndexError:
                    pass
        # Eliminate any parts right next to each other on same row only
        parts_copy = parts.copy()
        for part in parts_copy:
            part_row = part[0]
            if [part_row, part[1] + 1] in parts or [part_row, part[1] - 1] in parts:
                parts.remove(part)
                print(f"Removed {part} from {parts}")
        gears.append([pos, parts])
    return gears

def calculate_ratio(gear_parts):
    total_gear_ratio = 0
    for candidate in gear_parts:
        if len(candidate[1])==2:
            print(f"\nFound a candidate at {candidate[0]} with part locations{candidate[1]}")

            gear_ratio = 1
            # Search for the full number in the row
            for part_pos in candidate[1]:
                row_content = content_array[part_pos[0], :]
                # split on '.'
                min_index = part_pos[1] - 3 if part_pos[1] - 3 >= 0 else 0
                max_index = part_pos[1] + 3 if part_pos[1] + 3 <= len(row_content) else len(row_content)
                # Replace all not isalnum with '.'
                row_content = "".join([x if x.isalnum() else '.' for x in row_content])
                row_content = "".join(row_content[min_index:max_index]).split('.')
                # trim all special characters for all strings in the list
                # print(f"Found row content {row_content}")
                num = extract_number(content_array, part_pos)
                gear_ratio *= num
            total_gear_ratio += gear_ratio
            print(f"Found a gear ratio of {gear_ratio}, numbers were {gear_ratio//num}, {num}")
        else:
            print(f"\nFound a candidate at {candidate[0]} with part locations{candidate[1]} but wrong number of parts")
        # Display 3x3 grid around the candidate
        min_row = candidate[0][0] - 2 if candidate[0][0] - 2 >= 0 else 0
        max_row = candidate[0][0] + 2 if candidate[0][0] + 2 <= len(content_array) else len(content_array)
        min_col = candidate[0][1] - 3 if candidate[0][1] - 3 >= 0 else 0
        max_col = candidate[0][1] + 4 if candidate[0][1] + 4 <= len(content_array[0]) else len(content_array[0])
        print(content_array[min_row:max_row, min_col:max_col])
    return total_gear_ratio

# Find the index of 
content_array = np.array(input_content)
print(content_array)
print(content_array.shape)
# Print the index of all '*'s
gear_parts = find_parts(content_array)
print(gear_parts)
print(calculate_ratio(gear_parts))


# Found a candidate at (19, 63) with part locations[[18, 63], [20, 62], [20, 64]] but wrong number of parts
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '1' '1' '1' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '3' '0' '5' '.' '.']]

# Checking position (19, 63)
# Removed [18, 62] from [[18, 63], [18, 64], [20, 62], [20, 63], [20, 64]]
# Removed [18, 64] from [[18, 63], [20, 62], [20, 63], [20, 64]]
# Removed [20, 63] from [[18, 63], [20, 62], [20, 64]]
# Out:
# [['.' '.' '.' ... '.' '.' '.']
#  ['.' '.' '.' ... '.' '.' '.']
#  ['.' '.' '.' ... '.' '.' '.']
#  ...
#  ['.' '.' '.' ... '.' '.' '.']
#  ['.' '.' '.' ... '.' '.' '.']
#  ['.' '.' '.' ... '.' '.' '.']]
# (140, 140)
# Checking position (1, 72)
# Removed [0, 71] from [[0, 72], [2, 71]]
# Checking position (1, 119)
# Checking position (2, 34)
# Checking position (2, 45)
# Removed [1, 45] from [[1, 46], [3, 46]]
# Checking position (2, 113)
# Removed [1, 112] from [[1, 113], [3, 114]]
# Checking position (3, 7)
# Checking position (3, 63)
# Removed [2, 62] from [[2, 63], [4, 62], [4, 63]]
# Removed [4, 62] from [[2, 63], [4, 63]]
# Checking position (3, 109)
# Removed [2, 108] from [[2, 109], [4, 110]]
# Checking position (3, 131)
# Removed [2, 130] from [[2, 131]]
# Checking position (3, 133)
# Checking position (4, 29)
# Checking position (4, 72)
# Removed [5, 72] from [[3, 73], [5, 73]]
# Checking position (4, 102)
# Checking position (5, 37)
# Checking position (5, 129)
# Removed [6, 129] from [[4, 128], [6, 130]]
# Checking position (6, 89)
# Checking position (7, 133)
# Removed [8, 133] from [[8, 134]]
# Checking position (8, 10)
# Checking position (8, 76)
# Removed [7, 76] from [[7, 77], [9, 75], [9, 76], [9, 77]]
# Removed [9, 75] from [[7, 77], [9, 76], [9, 77]]
# Removed [9, 76] from [[7, 77], [9, 77]]
# Checking position (8, 83)
# Removed [7, 82] from [[7, 83], [7, 84], [9, 82]]
# Removed [7, 83] from [[7, 84], [9, 82]]
# Checking position (9, 95)
# Checking position (9, 104)
# Removed [8, 103] from [[8, 104], [8, 105], [10, 103]]
# Removed [8, 104] from [[8, 105], [10, 103]]
# Checking position (10, 6)
# Checking position (10, 15)
# Removed [11, 14] from [[9, 16], [11, 15], [11, 16]]
# Removed [11, 15] from [[9, 16], [11, 16]]
# Checking position (10, 84)
# Removed [11, 83] from [[9, 85], [11, 84]]
# Checking position (10, 129)
# Checking position (11, 116)
# Checking position (13, 27)
# Checking position (13, 74)
# Checking position (13, 90)
# Checking position (14, 37)
# Checking position (14, 133)
# Checking position (15, 54)
# Removed [14, 53] from [[14, 54], [16, 53], [16, 54]]
# Removed [16, 53] from [[14, 54], [16, 54]]
# Checking position (15, 82)
# Checking position (16, 9)
# Removed [17, 9] from [[15, 10], [17, 10]]
# Checking position (16, 28)
# Checking position (16, 72)
# Removed [15, 71] from [[15, 72], [17, 71], [17, 72]]
# Removed [17, 71] from [[15, 72], [17, 72]]
# Checking position (16, 77)
# Removed [17, 76] from [[15, 76], [17, 77], [17, 78]]
# Removed [17, 77] from [[15, 76], [17, 78]]
# Checking position (16, 93)
# Removed [15, 92] from [[15, 93], [15, 94], [17, 92], [17, 93]]
# Removed [15, 93] from [[15, 94], [17, 92], [17, 93]]
# Removed [17, 92] from [[15, 94], [17, 93]]
# Checking position (16, 106)
# Removed [15, 105] from [[15, 106], [17, 105], [17, 106]]
# Removed [17, 105] from [[15, 106], [17, 106]]
# Checking position (16, 115)
# Removed [17, 115] from [[15, 116], [17, 116]]
# Checking position (17, 23)
# Removed [16, 22] from [[16, 23], [18, 22], [18, 23]]
# Removed [18, 22] from [[16, 23], [18, 23]]
# Checking position (17, 40)
# Removed [18, 39] from [[18, 40]]
# Checking position (17, 47)
# Checking position (18, 55)
# Checking position (19, 36)
# Removed [18, 35] from [[18, 36]]
# Checking position (19, 63)
# Removed [18, 62] from [[18, 63], [18, 64], [20, 62], [20, 63], [20, 64]]
# Removed [18, 63] from [[18, 64], [20, 62], [20, 63], [20, 64]]
# Removed [20, 62] from [[18, 64], [20, 63], [20, 64]]
# Removed [20, 63] from [[18, 64], [20, 64]]
# Checking position (19, 102)
# Removed [18, 101] from [[18, 102], [20, 101], [20, 102], [20, 103]]
# Removed [20, 101] from [[18, 102], [20, 102], [20, 103]]
# Removed [20, 102] from [[18, 102], [20, 103]]
# Checking position (19, 136)
# Checking position (20, 10)
# Removed [21, 9] from [[19, 9], [21, 10]]
# Checking position (20, 20)
# Removed [21, 19] from [[19, 19], [21, 20]]
# Checking position (20, 31)
# Removed [19, 30] from [[19, 31], [21, 30], [21, 31], [21, 32]]
# Removed [21, 30] from [[19, 31], [21, 31], [21, 32]]
# Removed [21, 31] from [[19, 31], [21, 32]]
# Checking position (20, 44)
# Removed [19, 43] from [[19, 44], [21, 43], [21, 44], [21, 45]]
# Removed [21, 43] from [[19, 44], [21, 44], [21, 45]]
# Removed [21, 44] from [[19, 44], [21, 45]]
# Checking position (20, 83)
# Removed [19, 82] from [[19, 83], [19, 84], [21, 84]]
# Removed [19, 83] from [[19, 84], [21, 84]]
# Checking position (22, 68)
# Checking position (22, 76)
# Removed [21, 75] from [[21, 76], [23, 77]]
# Checking position (22, 106)
# Removed [21, 106] from [[21, 107], [23, 105], [23, 106]]
# Removed [23, 105] from [[21, 107], [23, 106]]
# Checking position (23, 132)
# Checking position (24, 4)
# Removed [23, 3] from [[23, 4], [25, 3], [25, 4]]
# Removed [25, 3] from [[23, 4], [25, 4]]
# Checking position (24, 41)
# Removed [23, 41] from [[23, 42], [25, 42]]
# Checking position (24, 56)
# Removed [23, 55] from [[23, 56], [23, 57], [25, 56], [25, 57]]
# Removed [23, 56] from [[23, 57], [25, 56], [25, 57]]
# Removed [25, 56] from [[23, 57], [25, 57]]
# Checking position (24, 62)
# Removed [23, 62] from [[23, 63], [25, 61], [25, 62]]
# Removed [25, 61] from [[23, 63], [25, 62]]
# Checking position (24, 124)
# Checking position (25, 50)
# Checking position (25, 67)
# Removed [24, 66] from [[24, 67], [24, 68], [26, 66], [26, 67]]
# Removed [24, 67] from [[24, 68], [26, 66], [26, 67]]
# Removed [26, 66] from [[24, 68], [26, 67]]
# Checking position (25, 99)
# Checking position (26, 14)
# Removed [27, 14] from [[25, 13], [27, 15]]
# Checking position (27, 7)
# Removed [26, 6] from [[26, 7], [26, 8], [28, 6], [28, 7]]
# Removed [26, 7] from [[26, 8], [28, 6], [28, 7]]
# Removed [28, 6] from [[26, 8], [28, 7]]
# Checking position (27, 48)
# Removed [28, 48] from [[28, 49]]
# Checking position (28, 20)
# Removed [27, 20] from [[27, 21], [29, 19], [29, 20]]
# Removed [29, 19] from [[27, 21], [29, 20]]
# Checking position (28, 87)
# Checking position (29, 40)
# Removed [30, 40] from [[28, 39], [30, 41]]
# Checking position (29, 45)
# Removed [28, 44] from [[28, 45], [30, 45], [30, 46]]
# Removed [30, 45] from [[28, 45], [30, 46]]
# Checking position (29, 67)
# Checking position (29, 79)
# Removed [30, 78] from [[28, 78], [30, 79]]
# Checking position (29, 126)
# Checking position (30, 24)
# Checking position (30, 100)
# Removed [29, 99] from [[29, 100], [29, 101], [31, 99]]
# Removed [29, 100] from [[29, 101], [31, 99]]
# Checking position (30, 124)
# Removed [31, 124] from [[31, 125]]
# Checking position (31, 37)
# Checking position (31, 52)
# Removed [32, 51] from [[30, 51], [32, 52], [32, 53]]
# Removed [32, 52] from [[30, 51], [32, 53]]
# Checking position (31, 110)
# Removed [32, 110] from [[30, 109], [32, 111]]
# Checking position (31, 117)
# Checking position (33, 106)
# Removed [32, 106] from [[32, 107], [34, 105]]
# Checking position (34, 25)
# Checking position (34, 48)
# Checking position (34, 84)
# Removed [33, 84] from [[33, 85], [35, 83], [35, 84], [35, 85]]
# Removed [35, 83] from [[33, 85], [35, 84], [35, 85]]
# Removed [35, 84] from [[33, 85], [35, 85]]
# Checking position (35, 55)
# Removed [34, 54] from [[34, 55], [36, 54], [36, 55], [36, 56]]
# Removed [36, 54] from [[34, 55], [36, 55], [36, 56]]
# Removed [36, 55] from [[34, 55], [36, 56]]
# Checking position (36, 47)
# Checking position (36, 77)
# Checking position (36, 109)
# Removed [35, 108] from [[35, 109], [35, 110], [37, 109], [37, 110]]
# Removed [35, 109] from [[35, 110], [37, 109], [37, 110]]
# Removed [37, 109] from [[35, 110], [37, 110]]
# Checking position (36, 132)
# Checking position (37, 25)
# Removed [38, 25] from [[36, 24], [38, 26]]
# Checking position (37, 34)
# Removed [36, 33] from [[36, 34], [38, 33]]
# Checking position (37, 63)
# Removed [36, 62] from [[36, 63]]
# Checking position (37, 68)
# Checking position (38, 36)
# Checking position (38, 51)
# Removed [37, 50] from [[37, 51], [39, 50]]
# Checking position (38, 105)
# Removed [37, 105] from [[37, 106], [39, 106]]
# Checking position (38, 134)
# Checking position (39, 67)
# Checking position (40, 82)
# Removed [41, 82] from [[39, 81], [41, 83]]
# Checking position (41, 57)
# Checking position (41, 103)
# Removed [40, 102] from [[40, 103], [40, 104], [42, 104]]
# Removed [40, 103] from [[40, 104], [42, 104]]
# Checking position (41, 124)
# Removed [40, 123] from [[40, 124], [40, 125], [42, 125]]
# Removed [40, 124] from [[40, 125], [42, 125]]
# Checking position (42, 3)
# Checking position (42, 55)
# Checking position (42, 71)
# Removed [41, 70] from [[41, 71]]
# Checking position (43, 65)
# Removed [42, 64] from [[42, 65], [44, 64]]
# Checking position (43, 88)
# Removed [44, 88] from [[44, 89]]
# Checking position (43, 108)
# Checking position (43, 131)
# Removed [42, 130] from [[42, 131], [44, 130]]
# Checking position (44, 8)
# Checking position (44, 25)
# Checking position (44, 83)
# Checking position (44, 102)
# Checking position (45, 13)
# Checking position (45, 96)
# Removed [46, 95] from [[44, 95], [46, 96], [46, 97]]
# Removed [46, 96] from [[44, 95], [46, 97]]
# Checking position (46, 59)
# Checking position (46, 118)
# Checking position (46, 132)
# Checking position (47, 24)
# Checking position (47, 38)
# Removed [46, 38] from [[46, 39], [48, 38], [48, 39]]
# Removed [48, 38] from [[46, 39], [48, 39]]
# Checking position (47, 53)
# Checking position (47, 129)
# Removed [48, 129] from [[48, 130]]
# Checking position (48, 17)
# Checking position (48, 103)
# Removed [49, 102] from [[47, 102], [49, 103]]
# Checking position (48, 122)
# Checking position (49, 50)
# Removed [48, 49] from [[48, 50], [50, 51]]
# Checking position (49, 70)
# Removed [48, 69] from [[48, 70], [50, 69], [50, 70], [50, 71]]
# Removed [50, 69] from [[48, 70], [50, 70], [50, 71]]
# Removed [50, 70] from [[48, 70], [50, 71]]
# Checking position (49, 115)
# Checking position (50, 93)
# Checking position (51, 15)
# Removed [50, 14] from [[50, 15], [52, 16]]
# Checking position (51, 66)
# Removed [52, 65] from [[52, 66]]
# Checking position (51, 111)
# Removed [52, 110] from [[50, 110], [52, 111]]
# Checking position (51, 122)
# Checking position (52, 12)
# Checking position (52, 32)
# Checking position (53, 26)
# Removed [52, 26] from [[52, 27], [54, 25], [54, 26]]
# Removed [54, 25] from [[52, 27], [54, 26]]
# Checking position (54, 4)
# Removed [53, 4] from [[53, 5], [55, 5]]
# Checking position (54, 63)
# Checking position (54, 75)
# Removed [53, 75] from [[53, 76], [55, 74], [55, 75]]
# Removed [55, 74] from [[53, 76], [55, 75]]
# Checking position (55, 120)
# Removed [54, 120] from [[54, 121], [56, 120]]
# Checking position (55, 133)
# Removed [56, 133] from [[54, 134], [56, 134]]
# Checking position (56, 30)
# Removed [55, 30] from [[55, 31], [57, 29]]
# Checking position (56, 43)
# Removed [57, 42] from [[55, 42], [57, 43], [57, 44]]
# Removed [57, 43] from [[55, 42], [57, 44]]
# Checking position (56, 51)
# Checking position (56, 92)
# Removed [57, 92] from [[55, 93], [57, 93]]
# Checking position (56, 128)
# Checking position (57, 68)
# Removed [56, 67] from [[56, 68], [56, 69], [58, 67]]
# Removed [56, 68] from [[56, 69], [58, 67]]
# Checking position (58, 133)
# Checking position (59, 7)
# Checking position (59, 28)
# Checking position (59, 113)
# Checking position (60, 45)
# Removed [59, 45] from [[59, 46], [61, 44], [61, 45]]
# Removed [61, 44] from [[59, 46], [61, 45]]
# Checking position (61, 3)
# Checking position (61, 32)
# Removed [60, 31] from [[60, 32], [60, 33], [62, 31]]
# Removed [60, 32] from [[60, 33], [62, 31]]
# Checking position (61, 89)
# Removed [62, 89] from [[60, 90], [62, 90]]
# Checking position (61, 102)
# Removed [60, 101] from [[60, 102]]
# Checking position (61, 129)
# Checking position (62, 22)
# Checking position (62, 70)
# Removed [61, 69] from [[61, 70], [63, 69]]
# Checking position (62, 79)
# Removed [61, 78] from [[61, 79], [63, 78], [63, 79], [63, 80]]
# Removed [63, 78] from [[61, 79], [63, 79], [63, 80]]
# Removed [63, 79] from [[61, 79], [63, 80]]
# Checking position (62, 122)
# Checking position (63, 95)
# Removed [62, 94] from [[62, 95], [62, 96], [64, 94]]
# Removed [62, 95] from [[62, 96], [64, 94]]
# Checking position (64, 38)
# Checking position (65, 29)
# Removed [64, 29] from [[64, 30], [66, 30]]
# Checking position (65, 54)
# Removed [64, 54] from [[64, 55], [66, 53]]
# Checking position (65, 59)
# Checking position (66, 18)
# Removed [65, 17] from [[65, 18], [67, 17]]
# Checking position (66, 97)
# Removed [65, 97] from [[65, 98], [67, 96], [67, 97]]
# Removed [67, 96] from [[65, 98], [67, 97]]
# Checking position (67, 9)
# Checking position (67, 90)
# Removed [66, 89] from [[66, 90], [68, 91]]
# Checking position (69, 36)
# Removed [68, 35] from [[68, 36], [68, 37], [70, 35], [70, 36], [70, 37]]
# Removed [68, 36] from [[68, 37], [70, 35], [70, 36], [70, 37]]
# Removed [70, 35] from [[68, 37], [70, 36], [70, 37]]
# Removed [70, 36] from [[68, 37], [70, 37]]
# Checking position (69, 43)
# Checking position (69, 88)
# Removed [68, 87] from [[68, 88], [70, 87], [70, 88], [70, 89]]
# Removed [70, 87] from [[68, 88], [70, 88], [70, 89]]
# Removed [70, 88] from [[68, 88], [70, 89]]
# Checking position (69, 127)
# Removed [68, 126] from [[68, 127], [68, 128], [70, 126], [70, 127], [70, 128]]
# Removed [68, 127] from [[68, 128], [70, 126], [70, 127], [70, 128]]
# Removed [70, 126] from [[68, 128], [70, 127], [70, 128]]
# Removed [70, 127] from [[68, 128], [70, 128]]
# Checking position (71, 10)
# Removed [70, 10] from [[70, 11], [72, 9], [72, 10]]
# Removed [72, 9] from [[70, 11], [72, 10]]
# Checking position (71, 84)
# Checking position (71, 130)
# Removed [70, 130] from [[70, 131], [72, 131]]
# Checking position (72, 102)
# Removed [73, 101] from [[71, 101], [73, 102]]
# Checking position (73, 16)
# Removed [72, 15] from [[72, 16], [74, 15], [74, 16]]
# Removed [74, 15] from [[72, 16], [74, 16]]
# Checking position (73, 105)
# Removed [74, 104] from [[72, 106], [74, 105], [74, 106]]
# Removed [74, 105] from [[72, 106], [74, 106]]
# Checking position (73, 116)
# Removed [72, 116] from [[72, 117], [74, 117]]
# Checking position (74, 43)
# Checking position (74, 91)
# Removed [73, 91] from [[73, 92], [75, 92]]
# Checking position (74, 123)
# Removed [75, 122] from [[73, 122], [75, 123], [75, 124]]
# Removed [75, 123] from [[73, 122], [75, 124]]
# Checking position (75, 63)
# Removed [74, 63] from [[74, 64], [76, 63], [76, 64]]
# Removed [76, 63] from [[74, 64], [76, 64]]
# Checking position (75, 108)
# Removed [74, 108] from [[74, 109], [76, 107], [76, 108], [76, 109]]
# Removed [76, 107] from [[74, 109], [76, 108], [76, 109]]
# Removed [76, 108] from [[74, 109], [76, 109]]
# Checking position (76, 25)
# Checking position (76, 135)
# Removed [75, 134] from [[75, 135], [77, 134], [77, 135]]
# Removed [77, 134] from [[75, 135], [77, 135]]
# Checking position (77, 21)
# Checking position (78, 3)
# Checking position (78, 37)
# Removed [79, 36] from [[77, 36], [79, 37]]
# Checking position (78, 39)
# Removed [79, 39] from [[77, 40], [79, 40]]
# Checking position (78, 81)
# Removed [77, 80] from [[77, 81], [79, 82]]
# Checking position (78, 86)
# Removed [77, 85] from [[77, 86], [79, 87]]
# Checking position (78, 114)
# Checking position (78, 130)
# Removed [77, 129] from [[77, 130], [77, 131], [79, 129]]
# Removed [77, 130] from [[77, 131], [79, 129]]
# Checking position (79, 44)
# Checking position (80, 121)
# Removed [79, 120] from [[79, 121], [79, 122], [81, 120]]
# Removed [79, 121] from [[79, 122], [81, 120]]
# Checking position (81, 32)
# Checking position (81, 40)
# Checking position (82, 92)
# Removed [81, 92] from [[81, 93], [83, 91], [83, 92]]
# Removed [83, 91] from [[81, 93], [83, 92]]
# Checking position (82, 129)
# Removed [81, 128] from [[81, 129], [81, 130], [83, 130]]
# Removed [81, 129] from [[81, 130], [83, 130]]
# Checking position (83, 24)
# Removed [84, 23] from [[82, 25], [84, 24], [84, 25]]
# Removed [84, 24] from [[82, 25], [84, 25]]
# Checking position (83, 69)
# Removed [82, 68] from [[82, 69], [82, 70], [84, 69]]
# Removed [82, 69] from [[82, 70], [84, 69]]
# Checking position (84, 4)
# Checking position (84, 51)
# Removed [83, 51] from [[83, 52], [85, 52]]
# Checking position (84, 76)
# Removed [85, 76] from [[83, 75], [85, 77]]
# Checking position (85, 32)
# Checking position (85, 38)
# Removed [84, 37] from [[84, 38], [84, 39], [86, 38], [86, 39]]
# Removed [84, 38] from [[84, 39], [86, 38], [86, 39]]
# Removed [86, 38] from [[84, 39], [86, 39]]
# Checking position (85, 123)
# Removed [84, 122] from [[84, 123], [86, 123], [86, 124]]
# Removed [86, 123] from [[84, 123], [86, 124]]
# Checking position (86, 90)
# Removed [85, 89] from [[85, 90], [85, 91], [87, 89], [87, 90], [87, 91]]
# Removed [85, 90] from [[85, 91], [87, 89], [87, 90], [87, 91]]
# Removed [87, 89] from [[85, 91], [87, 90], [87, 91]]
# Removed [87, 90] from [[85, 91], [87, 91]]
# Checking position (86, 101)
# Removed [85, 101] from [[85, 102], [87, 102]]
# Checking position (88, 7)
# Removed [87, 6] from [[87, 7], [87, 8], [89, 6], [89, 7], [89, 8]]
# Removed [87, 7] from [[87, 8], [89, 6], [89, 7], [89, 8]]
# Removed [89, 6] from [[87, 8], [89, 7], [89, 8]]
# Removed [89, 7] from [[87, 8], [89, 8]]
# Checking position (88, 49)
# Removed [87, 48] from [[87, 49], [89, 49], [89, 50]]
# Removed [89, 49] from [[87, 49], [89, 50]]
# Checking position (88, 108)
# Removed [87, 107] from [[87, 108], [87, 109], [89, 108], [89, 109]]
# Removed [87, 108] from [[87, 109], [89, 108], [89, 109]]
# Removed [89, 108] from [[87, 109], [89, 109]]
# Checking position (88, 117)
# Removed [87, 116] from [[87, 117], [87, 118], [89, 118]]
# Removed [87, 117] from [[87, 118], [89, 118]]
# Checking position (89, 62)
# Checking position (89, 71)
# Removed [88, 70] from [[88, 71], [90, 70], [90, 71]]
# Removed [90, 70] from [[88, 71], [90, 71]]
# Checking position (89, 115)
# Removed [90, 114] from [[88, 114], [90, 115]]
# Checking position (89, 135)
# Removed [90, 135] from [[90, 136]]
# Checking position (90, 45)
# Removed [89, 44] from [[89, 45], [91, 46]]
# Checking position (90, 75)
# Removed [89, 74] from [[89, 75]]
# Checking position (90, 95)
# Removed [91, 94] from [[91, 95]]
# Checking position (90, 103)
# Checking position (91, 10)
# Removed [90, 10] from [[90, 11], [92, 9]]
# Checking position (91, 87)
# Checking position (92, 18)
# Checking position (92, 40)
# Removed [91, 39] from [[91, 40], [91, 41], [93, 39], [93, 40], [93, 41]]
# Removed [91, 40] from [[91, 41], [93, 39], [93, 40], [93, 41]]
# Removed [93, 39] from [[91, 41], [93, 40], [93, 41]]
# Removed [93, 40] from [[91, 41], [93, 41]]
# Checking position (92, 129)
# Checking position (93, 76)
# Removed [94, 75] from [[92, 75], [94, 76], [94, 77]]
# Removed [94, 76] from [[92, 75], [94, 77]]
# Checking position (93, 113)
# Removed [92, 113] from [[92, 114], [94, 112], [94, 113]]
# Removed [94, 112] from [[92, 114], [94, 113]]
# Checking position (95, 32)
# Removed [94, 32] from [[94, 33], [96, 31]]
# Checking position (95, 61)
# Checking position (95, 93)
# Checking position (97, 3)
# Checking position (97, 24)
# Checking position (97, 37)
# Removed [96, 36] from [[96, 37], [98, 36]]
# Checking position (97, 63)
# Checking position (97, 91)
# Checking position (97, 98)
# Removed [96, 97] from [[96, 98], [96, 99]]
# Removed [96, 98] from [[96, 99]]
# Checking position (97, 110)
# Removed [96, 110] from [[96, 111], [98, 109], [98, 110], [98, 111]]
# Removed [98, 109] from [[96, 111], [98, 110], [98, 111]]
# Removed [98, 110] from [[96, 111], [98, 111]]
# Checking position (97, 136)
# Checking position (98, 11)
# Checking position (98, 16)
# Checking position (98, 72)
# Checking position (98, 126)
# Checking position (99, 28)
# Removed [98, 28] from [[98, 29], [100, 28], [100, 29]]
# Removed [100, 28] from [[98, 29], [100, 29]]
# Checking position (100, 22)
# Removed [99, 21] from [[99, 22], [99, 23], [101, 21], [101, 22]]
# Removed [99, 22] from [[99, 23], [101, 21], [101, 22]]
# Removed [101, 21] from [[99, 23], [101, 22]]
# Checking position (100, 90)
# Checking position (100, 98)
# Removed [99, 98] from [[99, 99], [101, 97], [101, 98], [101, 99]]
# Removed [101, 97] from [[99, 99], [101, 98], [101, 99]]
# Removed [101, 98] from [[99, 99], [101, 99]]
# Checking position (100, 126)
# Checking position (100, 133)
# Removed [99, 132] from [[99, 133], [101, 132]]
# Checking position (101, 51)
# Checking position (101, 72)
# Removed [100, 71] from [[100, 72], [100, 73], [102, 73]]
# Removed [100, 72] from [[100, 73], [102, 73]]
# Checking position (101, 106)
# Checking position (101, 120)
# Checking position (102, 8)
# Checking position (102, 42)
# Checking position (102, 81)
# Checking position (103, 100)
# Checking position (103, 134)
# Removed [102, 134] from [[102, 135], [104, 133], [104, 134]]
# Removed [104, 133] from [[102, 135], [104, 134]]
# Checking position (104, 20)
# Checking position (104, 31)
# Removed [105, 30] from [[103, 32], [105, 31]]
# Checking position (104, 51)
# Checking position (104, 56)
# Checking position (104, 67)
# Removed [103, 67] from [[103, 68], [105, 66], [105, 67], [105, 68]]
# Removed [105, 66] from [[103, 68], [105, 67], [105, 68]]
# Removed [105, 67] from [[103, 68], [105, 68]]
# Checking position (105, 44)
# Checking position (105, 86)
# Removed [104, 86] from [[104, 87], [106, 86], [106, 87]]
# Removed [106, 86] from [[104, 87], [106, 87]]
# Checking position (105, 113)
# Removed [104, 113] from [[104, 114], [106, 112]]
# Checking position (105, 136)
# Checking position (106, 55)
# Checking position (107, 35)
# Removed [106, 34] from [[106, 35], [106, 36], [108, 34]]
# Removed [106, 35] from [[106, 36], [108, 34]]
# Checking position (107, 40)
# Checking position (107, 121)
# Removed [106, 120] from [[106, 121], [108, 120]]
# Checking position (108, 95)
# Removed [107, 94] from [[107, 95], [107, 96], [109, 94], [109, 95], [109, 96]]
# Removed [107, 95] from [[107, 96], [109, 94], [109, 95], [109, 96]]
# Removed [109, 94] from [[107, 96], [109, 95], [109, 96]]
# Removed [109, 95] from [[107, 96], [109, 96]]
# Checking position (108, 113)
# Checking position (109, 59)
# Removed [110, 59] from [[108, 58], [110, 60]]
# Checking position (109, 107)
# Removed [108, 106] from [[108, 107], [110, 106], [110, 107]]
# Removed [110, 106] from [[108, 107], [110, 107]]
# Checking position (109, 125)
# Checking position (110, 48)
# Checking position (110, 71)
# Checking position (110, 89)
# Checking position (111, 38)
# Removed [110, 38] from [[110, 39], [112, 37]]
# Checking position (112, 28)
# Checking position (112, 55)
# Removed [111, 54] from [[111, 55], [113, 54], [113, 55], [113, 56]]
# Removed [113, 54] from [[111, 55], [113, 55], [113, 56]]
# Removed [113, 55] from [[111, 55], [113, 56]]
# Checking position (112, 83)
# Removed [111, 82] from [[111, 83], [111, 84], [113, 83], [113, 84]]
# Removed [111, 83] from [[111, 84], [113, 83], [113, 84]]
# Removed [113, 83] from [[111, 84], [113, 84]]
# Checking position (113, 41)
# Removed [112, 41] from [[112, 42], [114, 42]]
# Checking position (113, 70)
# Removed [112, 69] from [[112, 70], [112, 71], [114, 70], [114, 71]]
# Removed [112, 70] from [[112, 71], [114, 70], [114, 71]]
# Removed [114, 70] from [[112, 71], [114, 71]]
# Checking position (114, 92)
# Checking position (114, 98)
# Checking position (114, 109)
# Removed [113, 109] from [[113, 110], [115, 108], [115, 109]]
# Removed [115, 108] from [[113, 110], [115, 109]]
# Checking position (115, 12)
# Removed [114, 11] from [[114, 12], [114, 13], [116, 11], [116, 12]]
# Removed [114, 12] from [[114, 13], [116, 11], [116, 12]]
# Removed [116, 11] from [[114, 13], [116, 12]]
# Checking position (115, 21)
# Checking position (115, 118)
# Checking position (115, 123)
# Removed [114, 123] from [[114, 124]]
# Checking position (117, 41)
# Checking position (117, 135)
# Checking position (118, 8)
# Checking position (118, 87)
# Removed [119, 87] from [[117, 86], [119, 88]]
# Checking position (118, 94)
# Checking position (119, 16)
# Removed [120, 16] from [[118, 15], [120, 17]]
# Checking position (119, 20)
# Removed [118, 19] from [[118, 20], [120, 21]]
# Checking position (119, 40)
# Checking position (119, 46)
# Removed [118, 45] from [[118, 46], [120, 47]]
# Checking position (120, 81)
# Removed [121, 80] from [[119, 82], [121, 81]]
# Checking position (120, 98)
# Removed [119, 97] from [[119, 98], [119, 99], [121, 97], [121, 98], [121, 99]]
# Removed [119, 98] from [[119, 99], [121, 97], [121, 98], [121, 99]]
# Removed [121, 97] from [[119, 99], [121, 98], [121, 99]]
# Removed [121, 98] from [[119, 99], [121, 99]]
# Checking position (121, 62)
# Checking position (121, 77)
# Removed [120, 76] from [[120, 77], [122, 76], [122, 77]]
# Removed [122, 76] from [[120, 77], [122, 77]]
# Checking position (122, 26)
# Checking position (122, 40)
# Checking position (122, 69)
# Removed [123, 69] from [[123, 70]]
# Checking position (122, 102)
# Removed [121, 101] from [[121, 102], [121, 103], [123, 101], [123, 102]]
# Removed [121, 102] from [[121, 103], [123, 101], [123, 102]]
# Removed [123, 101] from [[121, 103], [123, 102]]
# Checking position (123, 11)
# Removed [122, 10] from [[122, 11], [122, 12], [124, 10]]
# Removed [122, 11] from [[122, 12], [124, 10]]
# Checking position (123, 58)
# Removed [122, 58] from [[122, 59], [124, 59]]
# Checking position (123, 93)
# Removed [122, 92] from [[122, 93]]
# Checking position (123, 114)
# Removed [122, 114] from [[122, 115], [124, 115]]
# Checking position (124, 25)
# Checking position (125, 34)
# Checking position (125, 106)
# Checking position (126, 50)
# Removed [125, 50] from [[125, 51], [127, 49]]
# Checking position (126, 57)
# Removed [125, 56] from [[125, 57], [127, 58]]
# Checking position (126, 67)
# Checking position (126, 97)
# Checking position (126, 136)
# Checking position (127, 10)
# Removed [126, 9] from [[126, 10], [128, 11]]
# Checking position (127, 43)
# Removed [126, 43] from [[126, 44], [128, 44]]
# Checking position (127, 74)
# Removed [128, 73] from [[126, 75], [128, 74], [128, 75]]
# Removed [128, 74] from [[126, 75], [128, 75]]
# Checking position (127, 88)
# Checking position (128, 32)
# Removed [127, 31] from [[127, 32], [127, 33], [129, 31]]
# Removed [127, 32] from [[127, 33], [129, 31]]
# Checking position (128, 80)
# Checking position (129, 7)
# Removed [128, 6] from [[128, 7], [128, 8], [130, 7], [130, 8]]
# Removed [128, 7] from [[128, 8], [130, 7], [130, 8]]
# Removed [130, 7] from [[128, 8], [130, 8]]
# Checking position (129, 20)
# Checking position (129, 57)
# Checking position (129, 98)
# Removed [128, 98] from [[128, 99], [130, 97], [130, 98], [130, 99]]
# Removed [130, 97] from [[128, 99], [130, 98], [130, 99]]
# Removed [130, 98] from [[128, 99], [130, 99]]
# Checking position (129, 114)
# Checking position (129, 127)
# Removed [128, 126] from [[128, 127], [130, 126], [130, 127]]
# Removed [130, 126] from [[128, 127], [130, 127]]
# Checking position (130, 81)
# Removed [131, 80] from [[131, 81]]
# Checking position (130, 94)
# Removed [129, 93] from [[129, 94], [129, 95], [131, 93], [131, 94], [131, 95]]
# Removed [129, 94] from [[129, 95], [131, 93], [131, 94], [131, 95]]
# Removed [131, 93] from [[129, 95], [131, 94], [131, 95]]
# Removed [131, 94] from [[129, 95], [131, 95]]
# Checking position (130, 103)
# Removed [129, 102] from [[129, 103], [131, 102], [131, 103]]
# Removed [131, 102] from [[129, 103], [131, 103]]
# Checking position (130, 108)
# Removed [129, 107] from [[129, 108], [131, 107]]
# Checking position (130, 135)
# Removed [131, 134] from [[129, 136], [131, 135]]
# Checking position (131, 12)
# Removed [130, 11] from [[130, 12], [130, 13], [132, 13]]
# Removed [130, 12] from [[130, 13], [132, 13]]
# Checking position (131, 23)
# Removed [130, 22] from [[130, 23], [132, 22]]
# Checking position (131, 47)
# Removed [130, 46] from [[130, 47], [132, 47], [132, 48]]
# Removed [132, 47] from [[130, 47], [132, 48]]
# Checking position (131, 73)
# Removed [130, 73] from [[130, 74], [132, 72]]
# Checking position (131, 89)
# Removed [130, 89] from [[130, 90], [132, 88], [132, 89]]
# Removed [132, 88] from [[130, 90], [132, 89]]
# Checking position (132, 60)
# Removed [131, 59] from [[131, 60], [133, 59], [133, 60], [133, 61]]
# Removed [133, 59] from [[131, 60], [133, 60], [133, 61]]
# Removed [133, 60] from [[131, 60], [133, 61]]
# Checking position (133, 25)
# Removed [132, 25] from [[132, 26], [134, 24], [134, 25]]
# Removed [134, 24] from [[132, 26], [134, 25]]
# Checking position (133, 31)
# Removed [132, 30] from [[132, 31], [134, 30]]
# Checking position (133, 119)
# Checking position (134, 92)
# Removed [133, 92] from [[133, 93], [135, 91], [135, 92]]
# Removed [135, 91] from [[133, 93], [135, 92]]
# Checking position (134, 135)
# Checking position (135, 8)
# Checking position (135, 49)
# Checking position (135, 65)
# Removed [136, 64] from [[134, 66], [136, 65], [136, 66]]
# Removed [136, 65] from [[134, 66], [136, 66]]
# Checking position (135, 124)
# Checking position (136, 22)
# Checking position (136, 38)
# Removed [135, 37] from [[135, 38]]
# Checking position (136, 43)
# Removed [135, 42] from [[135, 43], [137, 42], [137, 43], [137, 44]]
# Removed [137, 42] from [[135, 43], [137, 43], [137, 44]]
# Removed [137, 43] from [[135, 43], [137, 44]]
# Checking position (136, 51)
# Removed [135, 51] from [[135, 52], [137, 50], [137, 51], [137, 52]]
# Removed [137, 50] from [[135, 52], [137, 51], [137, 52]]
# Removed [137, 51] from [[135, 52], [137, 52]]
# Checking position (136, 103)
# Checking position (136, 110)
# Removed [135, 110] from [[135, 111], [137, 110], [137, 111]]
# Removed [137, 110] from [[135, 111], [137, 111]]
# Checking position (136, 132)
# Checking position (137, 7)
# Checking position (137, 17)
# Removed [136, 16] from [[136, 17], [138, 17], [138, 18]]
# Removed [138, 17] from [[136, 17], [138, 18]]
# Checking position (137, 86)
# Removed [138, 85] from [[136, 85], [138, 86]]
# Checking position (137, 120)
# Removed [136, 120] from [[136, 121], [138, 119], [138, 120]]
# Removed [138, 119] from [[136, 121], [138, 120]]
# Checking position (138, 28)
# Checking position (138, 96)
# [[(1, 72), [[0, 72], [2, 71]]], [(1, 119), [[1, 118], [1, 120]]], [(2, 34), [[1, 33], [3, 33]]], [(2, 45), [[1, 46], [3, 46]]], [(2, 113), [[1, 113], [3, 114]]], [(3, 7), [[2, 8], [4, 6]]], [(3, 63), [[2, 63], [4, 63]]], [(3, 109), [[2, 109], [4, 110]]], [(3, 131), [[2, 131]]], [(3, 133), [[2, 134], [4, 134]]], [(4, 29), [[4, 28], [5, 30]]], [(4, 72), [[3, 73], [5, 73]]], [(4, 102), [[3, 103], [5, 103]]], [(5, 37), [[5, 36], [5, 38]]], [(5, 129), [[4, 128], [6, 130]]], [(6, 89), [[5, 90]]], [(7, 133), [[8, 134]]], [(8, 10), [[7, 9], [9, 11]]], [(8, 76), [[7, 77], [9, 77]]], [(8, 83), [[7, 84], [9, 82]]], [(9, 95), [[10, 94]]], [(9, 104), [[8, 105], [10, 103]]], [(10, 6), [[10, 5], [10, 7]]], [(10, 15), [[9, 16], [11, 16]]], [(10, 84), [[9, 85], [11, 84]]], [(10, 129), [[10, 130], [11, 128]]], [(11, 116), [[10, 115], [11, 117]]], [(13, 27), [[12, 28], [13, 26]]], [(13, 74), [[12, 73], [13, 75]]], [(13, 90), [[12, 89], [12, 91]]], [(14, 37), [[13, 38], [15, 38]]], [(14, 133), [[13, 134], [14, 132]]], [(15, 54), [[14, 54], [16, 54]]], [(15, 82), [[14, 81], [16, 83]]], [(16, 9), [[15, 10], [17, 10]]], [(16, 28), [[16, 27], [17, 29]]], [(16, 72), [[15, 72], [17, 72]]], [(16, 77), [[15, 76], [17, 78]]], [(16, 93), [[15, 94], [17, 93]]], [(16, 106), [[15, 106], [17, 106]]], [(16, 115), [[15, 116], [17, 116]]], [(17, 23), [[16, 23], [18, 23]]], [(17, 40), [[18, 40]]], [(17, 47), [[16, 46], [17, 48]]], [(18, 55), [[18, 56], [19, 54]]], [(19, 36), [[18, 36]]], [(19, 63), [[18, 64], [20, 64]]], [(19, 102), [[18, 102], [20, 103]]], [(19, 136), [[19, 137], [20, 135]]], [(20, 10), [[19, 9], [21, 10]]], [(20, 20), [[19, 19], [21, 20]]], [(20, 31), [[19, 31], [21, 32]]], [(20, 44), [[19, 44], [21, 45]]], [(20, 83), [[19, 84], [21, 84]]], [(22, 68), [[22, 67], [22, 69]]], [(22, 76), [[21, 76], [23, 77]]], [(22, 106), [[21, 107], [23, 106]]], [(23, 132), [[22, 133], [23, 131]]], [(24, 4), [[23, 4], [25, 4]]], [(24, 41), [[23, 42], [25, 42]]], [(24, 56), [[23, 57], [25, 57]]], [(24, 62), [[23, 63], [25, 62]]], [(24, 124), [[23, 125], [25, 123]]], [(25, 50), [[25, 49], [26, 51]]], [(25, 67), [[24, 68], [26, 67]]], [(25, 99), [[25, 98], [26, 100]]], [(26, 14), [[25, 13], [27, 15]]], [(27, 7), [[26, 8], [28, 7]]], [(27, 48), [[28, 49]]], [(28, 20), [[27, 21], [29, 20]]], [(28, 87), [[28, 88], [29, 86]]], [(29, 40), [[28, 39], [30, 41]]], [(29, 45), [[28, 45], [30, 46]]], [(29, 67), [[28, 68], [30, 66]]], [(29, 79), [[28, 78], [30, 79]]], [(29, 126), [[28, 125], [29, 127]]], [(30, 24), [[30, 25], [31, 23]]], [(30, 100), [[29, 101], [31, 99]]], [(30, 124), [[31, 125]]], [(31, 37), [[31, 36], [32, 38]]], [(31, 52), [[30, 51], [32, 53]]], [(31, 110), [[30, 109], [32, 111]]], [(31, 117), [[31, 118], [32, 116]]], [(33, 106), [[32, 107], [34, 105]]], [(34, 25), [[33, 26], [34, 24]]], [(34, 48), [[33, 47], [35, 49]]], [(34, 84), [[33, 85], [35, 85]]], [(35, 55), [[34, 55], [36, 56]]], [(36, 47), [[35, 46]]], [(36, 77), [[35, 78], [36, 76]]], [(36, 109), [[35, 110], [37, 110]]], [(36, 132), [[36, 131]]], [(37, 25), [[36, 24], [38, 26]]], [(37, 34), [[36, 34], [38, 33]]], [(37, 63), [[36, 63]]], [(37, 68), [[37, 67], [37, 69]]], [(38, 36), [[39, 37]]], [(38, 51), [[37, 51], [39, 50]]], [(38, 105), [[37, 106], [39, 106]]], [(38, 134), [[37, 135], [39, 133]]], [(39, 67), [[39, 68], [40, 66]]], [(40, 82), [[39, 81], [41, 83]]], [(41, 57), [[40, 58]]], [(41, 103), [[40, 104], [42, 104]]], [(41, 124), [[40, 125], [42, 125]]], [(42, 3), [[41, 2], [41, 4]]], [(42, 55), [[42, 54], [43, 56]]], [(42, 71), [[41, 71]]], [(43, 65), [[42, 65], [44, 64]]], [(43, 88), [[44, 89]]], [(43, 108), [[42, 109], [44, 109]]], [(43, 131), [[42, 131], [44, 130]]], [(44, 8), [[45, 7]]], [(44, 25), [[44, 26], [45, 24]]], [(44, 83), [[44, 82], [44, 84]]], [(44, 102), [[44, 103], [45, 101]]], [(45, 13), [[44, 12], [46, 12]]], [(45, 96), [[44, 95], [46, 97]]], [(46, 59), [[45, 58], [46, 60]]], [(46, 118), [[46, 119]]], [(46, 132), [[46, 131], [46, 133]]], [(47, 24), [[48, 23], [48, 25]]],  ...
#
# Found a candidate at (1, 72) with part locations[[0, 72], [2, 71]]
# Found a gear ratio of 449280, numbers were 520, 864
# [['.' '5' '2' '0' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['8' '6' '4' '.' '.' '.' '.']]
#
# Found a candidate at (1, 119) with part locations[[1, 118], [1, 120]]
# Found a gear ratio of 78585, numbers were 465, 169
# [['.' '.' '.' '.' '.' '.' '.']
#  ['4' '6' '5' '*' '1' '6' '9']
#  ['.' '.' '.' '.' '.' '.' '.']]
#
# Found a candidate at (2, 34) with part locations[[1, 33], [3, 33]]
# Found a gear ratio of 12642, numbers were 21, 602
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '2' '1' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['6' '0' '2' '.' '.' '.' '.']]
#
# Found a candidate at (2, 45) with part locations[[1, 46], [3, 46]]
# Found a gear ratio of 410733, numbers were 971, 423
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '9' '7' '1' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['1' '.' '.' '.' '4' '2' '3']]
#
# Found a candidate at (2, 113) with part locations[[1, 113], [3, 114]]
# Found a gear ratio of 97644, numbers were 316, 309
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '3' '1' '6' '.' '.' '4']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '3' '0' '9']]
#
# Found a candidate at (3, 7) with part locations[[2, 8], [4, 6]]
# Found a gear ratio of 649297, numbers were 881, 737
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '8' '8' '1']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['7' '3' '7' '.' '.' '.' '.']]
#
# Found a candidate at (3, 63) with part locations[[2, 63], [4, 63]]
# Found a gear ratio of 194449, numbers were 577, 337
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '5' '7' '7' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '3' '3' '7' '.' '.' '.']]
#
# Found a candidate at (3, 109) with part locations[[2, 109], [4, 110]]
# Found a gear ratio of 113526, numbers were 742, 153
# [['.' '.' '.' '.' '.' '3' '1']
#  ['.' '7' '4' '2' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '1' '5' '3']]
#
# Found a candidate at (3, 131) with part locations[[2, 131]] but wrong number of parts
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '7' '1' '4' '.' '.' '2']
#  ['.' '.' '.' '*' '.' '*' '.']
#  ['0' '.' '.' '.' '.' '.' '6']]
#
# Found a candidate at (3, 133) with part locations[[2, 134], [4, 134]]
# Found a gear ratio of 155672, numbers were 244, 638
# [['.' '.' '.' '.' '.' '.' '.']
#  ['1' '4' '.' '.' '2' '4' '4']
#  ['.' '*' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '6' '3' '8']]
#
# Found a candidate at (4, 29) with part locations[[4, 28], [5, 30]]
# Found a gear ratio of 263541, numbers were 321, 821
# [['3' '5' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '6' '0']
#  ['3' '2' '1' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '8' '2' '1']]
#
# Found a candidate at (4, 72) with part locations[[3, 73], [5, 73]]
# Found a gear ratio of 148335, numbers were 899, 165
# [['8' '6' '4' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '8' '9' '9']
#  ['1' '1' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '1' '6' '5' '.']]
#
# Found a candidate at (4, 102) with part locations[[3, 103], [5, 103]]
# Found a gear ratio of 108080, numbers were 965, 112
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '9' '6' '5']
#  ['0' '5' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '1' '1' '2']]
#
# Found a candidate at (5, 37) with part locations[[5, 36], [5, 38]]
# Found a gear ratio of 153408, numbers were 544, 282
# [['.' '.' '.' '.' '.' '.' '3']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['5' '4' '4' '*' '2' '8' '2']
#  ['.' '.' '.' '.' '.' '.' '.']]
#
# Found a candidate at (5, 129) with part locations[[4, 128], [6, 130]]
# Found a gear ratio of 108290, numbers were 130, 833
# [['.' '.' '.' '.' '.' '*' '.']
#  ['1' '3' '0' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '8' '3' '3' '.']]
#
# Found a candidate at (6, 89) with part locations[[5, 90]] but wrong number of parts
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '8' '3' '6']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']]
#
# Found a candidate at (7, 133) with part locations[[8, 134]] but wrong number of parts
# [['.' '.' '.' '.' '.' '.' '.']
#  ['3' '3' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '5' '0' '4' '.']]
#
# Found a candidate at (8, 10) with part locations[[7, 9], [9, 11]]
# Found a gear ratio of 252320, numbers were 830, 304
# [['.' '.' '.' '.' '.' '.' '.']
#  ['8' '3' '0' '.' '.' '.' '3']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '3' '0' '4']]
#
# Found a candidate at (8, 76) with part locations[[7, 77], [9, 77]]
# Found a gear ratio of 13776, numbers were 21, 656
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '2' '1' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '6' '5' '6' '.' '.']]
#
# Found a candidate at (8, 83) with part locations[[7, 84], [9, 82]]
# Found a gear ratio of 179955, numbers were 279, 645
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '2' '7' '9' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['6' '4' '5' '.' '.' '9' '1']]
#
# Found a candidate at (9, 95) with part locations[[10, 94]] but wrong number of parts
# [['.' '.' '2' '2' '6' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['9' '9' '3' '.' '.' '.' '.']]
#
# Found a candidate at (9, 104) with part locations[[8, 105], [10, 103]]
# Found a gear ratio of 78720, numbers were 192, 410
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '1' '9' '2' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['4' '1' '0' '.' '.' '.' '.']]
#
# Found a candidate at (10, 6) with part locations[[10, 5], [10, 7]]
# Found a gear ratio of 141288, numbers were 841, 168
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['8' '4' '1' '*' '1' '6' '8']
#  ['.' '.' '.' '.' '.' '.' '.']]
#
# Found a candidate at (10, 15) with part locations[[9, 16], [11, 16]]
# Found a gear ratio of 926744, numbers were 938, 988
# [['.' '.' '.' '.' '.' '.' '.']
#  ['0' '4' '.' '.' '9' '3' '8']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '9' '8' '8' '.' '1']]
#
# Found a candidate at (10, 84) with part locations[[9, 85], [11, 84]]
# Found a gear ratio of 507464, numbers were 916, 554
# [['.' '.' '*' '.' '.' '.' '.']
#  ['4' '5' '.' '.' '9' '1' '6']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '5' '5' '4' '.' '.' '.']]
#
# Found a candidate at (10, 129) with part locations[[10, 130], [11, 128]]
# Found a gear ratio of 154830, numbers were 195, 794
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '1' '9' '5']
#  ['7' '9' '4' '.' '.' '.' '.']]
#
# Found a candidate at (11, 116) with part locations[[10, 115], [11, 117]]
# Found a gear ratio of 225400, numbers were 920, 245
# [['.' '.' '.' '.' '-' '.' '.']
#  ['9' '2' '0' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '2' '4' '5']
#  ['.' '.' '.' '.' '.' '.' '.']]
#
# Found a candidate at (13, 27) with part locations[[12, 28], [13, 26]]
# Found a gear ratio of 681542, numbers were 866, 787
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '8' '6' '6']
#  ['7' '8' '7' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']]
#
# Found a candidate at (13, 74) with part locations[[12, 73], [13, 75]]
# Found a gear ratio of 437157, numbers were 567, 771
# [['.' '.' '.' '.' '.' '.' '.']
#  ['5' '6' '7' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '7' '7' '1']
#  ['.' '.' '.' '.' '.' '.' '.']]
#
# Found a candidate at (13, 90) with part locations[[12, 89], [12, 91]]
# Found a gear ratio of 919581, numbers were 949, 969
# [['.' '.' '.' '.' '.' '.' '.']
#  ['9' '4' '9' '.' '9' '6' '9']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['-' '.' '.' '.' '.' '.' '.']]
#
# Found a candidate at (14, 37) with part locations[[13, 38], [15, 38]]
# Found a gear ratio of 174825, numbers were 189, 925
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '1' '8' '9']
#  ['6' '1' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '9' '2' '5']]
#
# Found a candidate at (14, 133) with part locations[[13, 134], [14, 132]]
# Found a gear ratio of 24921, numbers were 639, 39
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '6' '3' '9']
#  ['.' '3' '9' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '7']]
#
# Found a candidate at (15, 54) with part locations[[14, 54], [16, 54]]
# Found a gear ratio of 326872, numbers were 449, 728
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '4' '4' '9' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '7' '2' '8' '.' '.' '.']]
#
# Found a candidate at (15, 82) with part locations[[14, 81], [16, 83]]
# Found a gear ratio of 332304, numbers were 344, 966
# [['.' '.' '.' '.' '.' '.' '.']
#  ['3' '4' '4' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '9' '6' '6']]
#
# Found a candidate at (16, 9) with part locations[[15, 10], [17, 10]]
# Found a gear ratio of 38808, numbers were 792, 49
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '7' '9' '2']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '4' '9' '.' '.']]
#
# Found a candidate at (16, 28) with part locations[[16, 27], [17, 29]]
# Found a gear ratio of 250516, numbers were 644, 389
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['6' '4' '4' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '3' '8' '9']]
#
# Found a candidate at (16, 72) with part locations[[15, 72], [17, 72]]
# Found a gear ratio of 141925, numbers were 175, 811
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '1' '7' '5' '.' '2' '3']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '8' '1' '1' '.' '.' '.']]
#
# Found a candidate at (16, 77) with part locations[[15, 76], [17, 78]]
# Found a gear ratio of 75864, numbers were 232, 327
# [['.' '.' '.' '.' '.' '3' '4']
#  ['2' '3' '2' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '3' '2' '7' '.' '.']]
#
# Found a candidate at (16, 93) with part locations[[15, 94], [17, 93]]
# Found a gear ratio of 93600, numbers were 156, 600
# [['.' '.' '.' '.' '.' '.' '.']
#  ['7' '.' '1' '5' '6' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '6' '0' '0' '.' '.' '.']]
#
# Found a candidate at (16, 106) with part locations[[15, 106], [17, 106]]
# Found a gear ratio of 88074, numbers were 378, 233
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '3' '7' '8' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '2' '3' '3' '.' '.' '.']]
#
# Found a candidate at (16, 115) with part locations[[15, 116], [17, 116]]
# Found a gear ratio of 58560, numbers were 183, 320
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '1' '8' '3']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '3' '2' '0' '.']]
#
# Found a candidate at (17, 23) with part locations[[16, 23], [18, 23]]
# Found a gear ratio of 247345, numbers were 955, 259
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '9' '5' '5' '.' '6' '4']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '2' '5' '9' '.' '.' '.']]
#
# Found a candidate at (17, 40) with part locations[[18, 40]] but wrong number of parts
# [['.' '9' '2' '5' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '6' '4' '6' '.' '.' '.']]
#
# Found a candidate at (17, 47) with part locations[[16, 46], [17, 48]]
# Found a gear ratio of 494508, numbers were 609, 812
# [['.' '.' '.' '.' '.' '.' '.']
#  ['6' '0' '9' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '8' '1' '2']
#  ['.' '.' '.' '.' '.' '.' '.']]
#
# Found a candidate at (18, 55) with part locations[[18, 56], [19, 54]]
# Found a gear ratio of 158304, numbers were 194, 816
# [['7' '2' '8' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '1' '9' '4']
#  ['8' '1' '6' '.' '.' '.' '.']]
#
# Found a candidate at (19, 36) with part locations[[18, 36]] but wrong number of parts
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '6' '2' '9' '.' '6' '4']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']]
#
# Found a candidate at (19, 63) with part locations[[18, 64], [20, 64]]
# Found a gear ratio of 33855, numbers were 111, 305
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '1' '1' '1' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '3' '0' '5' '.' '.']]
#
# Found a candidate at (19, 102) with part locations[[18, 102], [20, 103]]
# Found a gear ratio of 899198, numbers were 998, 901
# [['.' '.' '.' '.' '.' '2' '3']
#  ['.' '9' '9' '8' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '9' '0' '1' '.' '.']]
#
# Found a candidate at (19, 136) with part locations[[19, 137], [20, 135]]
# Found a gear ratio of 10000, numbers were 200, 50
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '2' '0' '0']
#  ['.' '5' '0' '.' '.' '.' '.']]
#
# Found a candidate at (20, 10) with part locations[[19, 9], [21, 10]]
# Found a gear ratio of 241536, numbers were 444, 544
# [['.' '.' '.' '.' '.' '.' '.']
#  ['4' '4' '4' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '5' '4' '4' '.' '.' '.']]
#
# Found a candidate at (20, 20) with part locations[[19, 19], [21, 20]]
# Found a gear ratio of 605880, numbers were 648, 935
# [['.' '.' '.' '.' '2' '5' '9']
#  ['6' '4' '8' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '9' '3' '5' '.' '.' '.']]
#
# Found a candidate at (20, 31) with part locations[[19, 31], [21, 32]]
# Found a gear ratio of 52976, numbers were 154, 344
# [['.' '.' '.' '.' '.' '.' '6']
#  ['.' '1' '5' '4' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '3' '4' '4' '.' '.']]
#
# Found a candidate at (20, 44) with part locations[[19, 44], [21, 45]]
# Found a gear ratio of 69642, numbers were 657, 106
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '6' '5' '7' '.' '.' '$']
#  ['.' '.' '.' '*' '.' '.' '2']
#  ['.' '.' '1' '0' '6' '.' '.']]
#
# Found a candidate at (20, 83) with part locations[[19, 84], [21, 84]]
# Found a gear ratio of 104427, numbers were 123, 849
# [['%' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '1' '2' '3' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '8' '4' '9']]
#
# Found a candidate at (22, 68) with part locations[[22, 67], [22, 69]]
# Found a gear ratio of 24585, numbers were 447, 55
# [['.' '.' '.' '.' '5' '1' '0']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['4' '4' '7' '*' '5' '5' '.']
#  ['.' '.' '.' '.' '.' '.' '.']]
#
# Found a candidate at (22, 76) with part locations[[21, 76], [23, 77]]
# Found a gear ratio of 31165, numbers were 271, 115
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '2' '7' '1' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '1' '1' '5']]
#
# Found a candidate at (22, 106) with part locations[[21, 107], [23, 106]]
# Found a gear ratio of 34710, numbers were 890, 39
# [['1' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '8' '9' '0' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '3' '9' '.' '.' '.']]
#
# Found a candidate at (23, 132) with part locations[[22, 133], [23, 131]]
# Found a gear ratio of 219061, numbers were 439, 499
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '4' '3' '9']
#  ['4' '9' '9' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']]
#
# Found a candidate at (24, 4) with part locations[[23, 4], [25, 4]]
# Found a gear ratio of 629775, numbers were 675, 933
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '6' '7' '5' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '9' '3' '3' '.' '.' '.']]
#
# Found a candidate at (24, 41) with part locations[[23, 42], [25, 42]]
# Found a gear ratio of 131664, numbers were 211, 624
# [['9' '1' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '2' '1' '1' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '6' '2' '4']]
#
# Found a candidate at (24, 56) with part locations[[23, 57], [25, 57]]
# Found a gear ratio of 506308, numbers were 814, 622
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '8' '1' '4' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '6' '2' '2' '.']]
#
# Found a candidate at (24, 62) with part locations[[23, 63], [25, 62]]
# Found a gear ratio of 8074, numbers were 22, 367
# [['.' '.' '.' '.' '.' '.' '4']
#  ['.' '.' '.' '2' '2' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '3' '6' '7' '.' '.' '.']]
#
# ...
# Found a gear ratio of 401574, numbers were 527, 762
# [['8' '4' '%' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '5' '2' '7']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '7' '6' '2' '.' '.' '.']]
#
# Found a candidate at (120, 98) with part locations[[119, 99], [121, 99]]
# Found a gear ratio of 41820, numbers were 123, 340
# [['.' '.' '.' '.' '.' '.' '&']
#  ['.' '.' '1' '2' '3' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '3' '4' '0' '.' '3']]
#
# Found a candidate at (121, 62) with part locations[[120, 61], [120, 63]]
# Found a gear ratio of 359264, numbers were 436, 824
# [['.' '.' '.' '.' '.' '.' '.']
#  ['4' '3' '6' '.' '8' '2' '4']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['2' '1' '.' '.' '.' '.' '1']]
#
# Found a candidate at (121, 77) with part locations[[120, 77], [122, 77]]
# Found a gear ratio of 255611, numbers were 577, 443
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '5' '7' '7' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '7' '6']
#  ['.' '4' '4' '3' '.' '.' '.']]
#
# Found a candidate at (122, 26) with part locations[[122, 25], [123, 27]]
# Found a gear ratio of 371025, numbers were 873, 425
# [['2' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['8' '7' '3' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '4' '2' '5']]
#
# Found a candidate at (122, 40) with part locations[[121, 39], [122, 41]]
# Found a gear ratio of 126846, numbers were 174, 729
# [['.' '.' '.' '.' '7' '1' '0']
#  ['1' '7' '4' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '7' '2' '9']
#  ['.' '.' '.' '.' '.' '.' '.']]
#
# Found a candidate at (122, 69) with part locations[[123, 70]] but wrong number of parts
# [['.' '.' '.' '.' '7' '2' '7']
#  ['.' '&' '.' '.' '.' '.' '.']
#  ['0' '2' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '2' '8' '6' '.']]
#
# Found a candidate at (122, 102) with part locations[[121, 103], [123, 102]]
# Found a gear ratio of 178464, numbers were 312, 572
# [['.' '.' '.' '.' '.' '.' '.']
#  ['0' '.' '3' '1' '2' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '5' '7' '2' '.' '.' '.']]
#
# Found a candidate at (123, 11) with part locations[[122, 12], [124, 10]]
# Found a gear ratio of 139880, numbers were 269, 520
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '2' '6' '9' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['5' '2' '0' '.' '.' '7' '6']]
#
# Found a candidate at (123, 58) with part locations[[122, 59], [124, 59]]
# Found a gear ratio of 26001, numbers were 321, 81
# [['.' '.' '.' '.' '.' '.' '.']
#  ['5' '.' '.' '3' '2' '1' '.']
#  ['.' '$' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '8' '1' '.']]
#
# Found a candidate at (123, 93) with part locations[[122, 93]] but wrong number of parts
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '2' '0' '5' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']]
#
# Found a candidate at (123, 114) with part locations[[122, 115], [124, 115]]
# Found a gear ratio of 1365, numbers were 15, 91
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '1' '5' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '9' '1' '.']]
#
# Found a candidate at (124, 25) with part locations[[124, 24], [125, 26]]
# Found a gear ratio of 53280, numbers were 74, 720
# [['.' '8' '7' '3' '*' '.' '.']
#  ['.' '.' '.' '.' '.' '4' '2']
#  ['.' '7' '4' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '7' '2' '0']]
#
# Found a candidate at (125, 34) with part locations[[125, 33], [126, 35]]
# Found a gear ratio of 119145, numbers were 169, 705
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['1' '6' '9' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '7' '0' '5']]
#
# Found a candidate at (125, 106) with part locations[[125, 105], [126, 107]]
# Found a gear ratio of 78480, numbers were 720, 109
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['7' '2' '0' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '1' '0' '9']]
#
# Found a candidate at (126, 50) with part locations[[125, 51], [127, 49]]
# Found a gear ratio of 137924, numbers were 164, 841
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '1' '6' '4' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['8' '4' '1' '.' '.' '.' '.']]
#
# Found a candidate at (126, 57) with part locations[[125, 57], [127, 58]]
# Found a gear ratio of 48636, numbers were 193, 252
# [['.' '.' '.' '.' '.' '8' '1']
#  ['.' '1' '9' '3' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['+' '.' '.' '.' '2' '5' '2']]
#
# Found a candidate at (126, 67) with part locations[[125, 66], [127, 66]]
# Found a gear ratio of 858364, numbers were 971, 884
# [['.' '.' '.' '.' '.' '.' '.']
#  ['9' '7' '1' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['8' '8' '4' '.' '.' '.' '.']]
#
# Found a candidate at (126, 97) with part locations[[125, 96], [125, 98]]
# Found a gear ratio of 160992, numbers were 559, 288
# [['.' '.' '.' '.' '.' '.' '.']
#  ['5' '5' '9' '.' '2' '8' '8']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']]
#
# Found a candidate at (126, 136) with part locations[[126, 135], [127, 137]]
# Found a gear ratio of 136906, numbers were 254, 539
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['2' '5' '4' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '5' '3' '9']]
#
# Found a candidate at (127, 10) with part locations[[126, 10], [128, 11]]
# Found a gear ratio of 273079, numbers were 383, 713
# [['.' '.' '.' '.' '.' '+' '.']
#  ['.' '3' '8' '3' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['1' '1' '.' '.' '7' '1' '3']]
#
# Found a candidate at (127, 43) with part locations[[126, 44], [128, 44]]
# Found a gear ratio of 25179, numbers were 763, 33
# [['.' '#' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '7' '6' '3' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '3' '3' '.']]
#
# Found a candidate at (127, 74) with part locations[[126, 75], [128, 75]]
# Found a gear ratio of 4842, numbers were 6, 807
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '6' '.' '2']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['1' '.' '8' '0' '7' '.' '.']]
#
# Found a candidate at (127, 88) with part locations[[128, 87], [128, 89]]
# Found a gear ratio of 420080, numbers were 472, 890
# [['9' '9' '1' '.' '.' '.' '%']
#  ['.' '.' '.' '.' '.' '8' '7']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['4' '7' '2' '.' '8' '9' '0']]
#
# Found a candidate at (128, 32) with part locations[[127, 33], [129, 31]]
# Found a gear ratio of 5650, numbers were 226, 25
# [['.' '.' '.' '.' '.' '.' '7']
#  ['.' '.' '2' '2' '6' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '2' '5' '.' '.' '.' '.']]
#
# Found a candidate at (128, 80) with part locations[[127, 81], [129, 79]]
# Found a gear ratio of 6576, numbers were 48, 137
# [['2' '7' '0' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '4' '8' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['1' '3' '7' '.' '.' '.' '.']]
#
# Found a candidate at (129, 7) with part locations[[128, 8], [130, 8]]
# Found a gear ratio of 81990, numbers were 911, 90
# [['.' '.' '.' '.' '.' '.' '*']
#  ['.' '.' '9' '1' '1' '.' '.']
#  ['%' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '9' '0' '.' '.']]
#
# Found a candidate at (129, 20) with part locations[[128, 19], [128, 21]]
# Found a gear ratio of 114048, numbers were 192, 594
# [['.' '.' '.' '.' '.' '.' '.']
#  ['1' '9' '2' '.' '5' '9' '4']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '9' '4']]
#
# Found a candidate at (129, 57) with part locations[[129, 58], [130, 56]]
# Found a gear ratio of 62700, numbers were 475, 132
# [['+' '.' '.' '.' '2' '5' '2']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '4' '7' '5']
#  ['1' '3' '2' '.' '.' '.' '.']]
#
# Found a candidate at (129, 98) with part locations[[128, 99], [130, 99]]
# Found a gear ratio of 512330, numbers were 563, 910
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '5' '6' '3' '.']
#  ['3' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '9' '1' '0' '.' '.']]
#
# Found a candidate at (129, 114) with part locations[[129, 113], [130, 115]]
# Found a gear ratio of 141183, numbers were 249, 567
# [['.' '.' '.' '.' '6' '7' '8']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['2' '4' '9' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '5' '6' '7']]
#
# Found a candidate at (129, 127) with part locations[[128, 127], [130, 127]]
# Found a gear ratio of 125280, numbers were 522, 240
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '5' '2' '2' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '5' '4']
#  ['.' '2' '4' '0' '.' '.' '.']]
#
# Found a candidate at (130, 81) with part locations[[131, 81]] but wrong number of parts
# [['.' '.' '*' '.' '.' '.' '.']
#  ['3' '7' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '5' '0' '6' '.' '.' '.']]
#
# Found a candidate at (130, 94) with part locations[[129, 95], [131, 95]]
# Found a gear ratio of 624215, numbers were 953, 655
# [['0' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '9' '5' '3' '.' '.']
#  ['7' '.' '.' '*' '.' '.' '9']
#  ['.' '.' '6' '5' '5' '.' '.']]
#
# Found a candidate at (130, 103) with part locations[[129, 103], [131, 103]]
# Found a gear ratio of 10620, numbers were 36, 295
# [['3' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '3' '6' '.' '.' '1']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '2' '9' '5' '.' '7' '7']]
#
# Found a candidate at (130, 108) with part locations[[129, 108], [131, 107]]
# Found a gear ratio of 97125, numbers were 125, 777
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '1' '2' '5' '.' '.' '2']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['7' '7' '7' '.' '.' '.' '.']]
#
# Found a candidate at (130, 135) with part locations[[129, 136], [131, 135]]
# Found a gear ratio of 623616, numbers were 696, 896
# [['/' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '6' '9' '6']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '8' '9' '6' '.' '.' '.']]
#
# Found a candidate at (131, 12) with part locations[[130, 13], [132, 13]]
# Found a gear ratio of 101010, numbers were 273, 370
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '2' '7' '3' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['7' '9' '.' '.' '3' '7' '0']]
#
# Found a candidate at (131, 23) with part locations[[130, 23], [132, 22]]
# Found a gear ratio of 77926, numbers were 94, 829
# [['*' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '9' '4' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['8' '2' '9' '.' '.' '3' '5']]
#
# Found a candidate at (131, 47) with part locations[[130, 47], [132, 48]]
# Found a gear ratio of 50692, numbers were 667, 76
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '6' '6' '7' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '7' '6' '.' '.']]
#
# Found a candidate at (131, 73) with part locations[[130, 74], [132, 72]]
# Found a gear ratio of 116640, numbers were 120, 972
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '1' '2' '0' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['9' '7' '2' '.' '.' '.' '.']]
#
# Found a candidate at (131, 89) with part locations[[130, 90], [132, 89]]
# Found a gear ratio of 506022, numbers were 697, 726
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '6' '9' '7' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '7' '2' '6' '.' '.' '.']]
#
# Found a candidate at (132, 60) with part locations[[131, 60], [133, 61]]
# Found a gear ratio of 228480, numbers were 595, 384
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '5' '9' '5' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '3' '8' '4' '.' '.']]
#
# Found a candidate at (133, 25) with part locations[[132, 26], [134, 25]]
# Found a gear ratio of 282664, numbers were 356, 794
# [['.' '*' '.' '.' '.' '.' '.']
#  ['9' '.' '.' '3' '5' '6' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '7' '9' '4' '.' '.' '7']]
#
# Found a candidate at (133, 31) with part locations[[132, 31], [134, 30]]
# Found a gear ratio of 463749, numbers were 611, 759
# [['.' '.' '.' '.' '.' '2' '9']
#  ['.' '6' '1' '1' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['7' '5' '9' '.' '.' '.' '.']]
#
# Found a candidate at (133, 119) with part locations[[132, 120], [134, 120]]
# Found a gear ratio of 395433, numbers were 829, 477
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '8' '2' '9']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '4' '7' '7']]
#
# Found a candidate at (134, 92) with part locations[[133, 93], [135, 92]]
# Found a gear ratio of 53013, numbers were 431, 123
# [['6' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '4' '3' '1' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '1' '2' '3' '.' '5' '7']]
#
# Found a candidate at (134, 135) with part locations[[134, 134], [135, 136]]
# Found a gear ratio of 207765, numbers were 729, 285
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['7' '2' '9' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '2' '8' '5']]
#
# Found a candidate at (135, 8) with part locations[[134, 9], [135, 7]]
# Found a gear ratio of 292744, numbers were 296, 989
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '2' '9' '6']
#  ['9' '8' '9' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']]
#
# Found a candidate at (135, 49) with part locations[[134, 48], [136, 48]]
# Found a gear ratio of 202370, numbers were 590, 343
# [['.' '.' '.' '.' '.' '.' '.']
#  ['5' '9' '0' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '4' '8']
#  ['3' '4' '3' '.' '.' '*' '.']]
#
# Found a candidate at (135, 65) with part locations[[134, 66], [136, 66]]
# Found a gear ratio of 207460, numbers were 410, 506
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '4' '1' '0']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '5' '0' '6' '.' '.']]
#
# Found a candidate at (135, 124) with part locations[[134, 125]] but wrong number of parts
# [['.' '.' '.' '.' '.' '.' '.']
#  ['7' '7' '.' '.' '3' '4' '2']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['0' '0' '.' '.' '.' '.' '.']]
#
# Found a candidate at (136, 22) with part locations[[136, 21], [136, 23]]
# Found a gear ratio of 108839, numbers were 857, 127
# [['7' '1' '5' '.' '7' '9' '4']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['8' '5' '7' '*' '1' '2' '7']
#  ['.' '.' '.' '.' '.' '.' '.']]
#
# Found a candidate at (136, 38) with part locations[[135, 38]] but wrong number of parts
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '5' '6' '8' '.' '.' '5']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']]
#
# Found a candidate at (136, 43) with part locations[[135, 43], [137, 44]]
# Found a gear ratio of 199279, numbers were 571, 349
# [['.' '.' '.' '.' '.' '.' '5']
#  ['.' '5' '7' '1' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '3']
#  ['.' '.' '3' '4' '9' '.' '.']]
#
# Found a candidate at (136, 51) with part locations[[135, 52], [137, 52]]
# Found a gear ratio of 461160, numbers were 488, 945
# [['0' '.' '.' '.' '.' '.' '.']
#  ['.' '*' '.' '4' '8' '8' '.']
#  ['3' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '9' '4' '5' '.' '.']]
#
# Found a candidate at (136, 103) with part locations[[137, 102], [137, 104]]
# Found a gear ratio of 21186, numbers were 33, 642
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '3' '3' '.' '6' '4' '2']]
#
# Found a candidate at (136, 110) with part locations[[135, 111], [137, 111]]
# Found a gear ratio of 425828, numbers were 988, 431
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '9' '8' '8' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '4' '3' '1' '.']]
#
# Found a candidate at (136, 132) with part locations[[137, 133]] but wrong number of parts
# [['.' '.' '.' '7' '2' '9' '*']
#  ['$' '.' '.' '.' '.' '.' '.']
#  ['2' '6' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '9' '6' '8']]
#
# Found a candidate at (137, 7) with part locations[[137, 8], [138, 6]]
# Found a gear ratio of 128927, numbers were 563, 229
# [['.' '9' '8' '9' '*' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '5' '6' '3']
#  ['2' '2' '9' '.' '.' '.' '.']]
#
# Found a candidate at (137, 17) with part locations[[136, 17], [138, 18]]
# Found a gear ratio of 32016, numbers were 667, 48
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '6' '6' '7' '.' '8' '5']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '4' '8' '.' '.']]
#
# Found a candidate at (137, 86) with part locations[[136, 85], [138, 86]]
# Found a gear ratio of 232165, numbers were 295, 787
# [['.' '.' '.' '.' '.' '.' '.']
#  ['2' '9' '5' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '7' '8' '7' '.' '.' '.']]
#
# Found a candidate at (137, 120) with part locations[[136, 121], [138, 120]]
# Found a gear ratio of 532200, numbers were 600, 887
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '6' '0' '0' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '8' '8' '7' '.' '.' '.']]
#
# Found a candidate at (138, 28) with part locations[[139, 29]] but wrong number of parts
# [['7' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['9' '.' '.' '.' '5' '1' '5']]
#
# Found a candidate at (138, 96) with part locations[[139, 95], [139, 97]]
# Found a gear ratio of 615909, numbers were 633, 973
# [['.' '.' '.' '.' '.' '.' '.']
#  ['4' '%' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['6' '3' '3' '.' '9' '7' '3']]
# 73646890

# %%
# Errors
# Found a gear ratio of 5576, numbers were 164, 34
# Found a gear ratio of 8946, numbers were 9, 994
# Found a gear ratio of 46116, numbers were 854, 54


# Expected
# Found a gear ratio of 1148, numbers were 164, 7
# Found a gear ratio of 2982, numbers were 3, 994
# Found a gear ratio of 5124, numbers were 854, 6



# Found a candidate at (55, 120) with part locations[[54, 121], [56, 120]]
# Found a gear ratio of 5576, numbers were 164, 34
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '1' '6' '4' '.']
#  ['.' '$' '.' '*' '.' '.' '.']
#  ['3' '4' '.' '7' '.' '.' '.']]

# Found a candidate at (46, 132) with part locations[[46, 131], [46, 133]]
# Found a gear ratio of 8946, numbers were 9, 994
# [['2' '8' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '3' '*' '9' '9' '4']
#  ['*' '.' '.' '.' '.' '.' '.']]

# Found a candidate at (42, 3) with part locations[[41, 2], [41, 4]]
# Found a gear ratio of 46116, numbers were 854, 54
# [['.' '.' '.' '.' '.' '.' '@']
#  ['8' '5' '4' '.' '6' '.' '.']
#  ['.' '.' '.' '*' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']]

# %%
def file_to_list(filename: str) -> list:
    """
    Read the file and return a list of the strings of each line.
    :param filename:
    :return content:
    """
    with open(filename) as f:
        content = f.readlines()
    content = [x.strip() for x in content]
    return content

def list_of_strings_to_list_of_lists(list_of_strings: list) -> list:
    """
    Convert a list of strings to a list of lists.
    :param list_of_strings:
    :return list_of_lists:
    """
    list_of_lists = []
    for string in list_of_strings:
        list_of_lists.append([x for x in string])
    return list_of_lists

def is_adjacent_to_symbol(list_of_lists, row, col) -> (bool, tuple):
    """
    Check if the character at the given row and column is adjacent to a symbol.
    Get the coordinates of the adjacent symbol.
    :param list_of_lists:
    :param row:
    :param col:
    :return:
    """
    # Directions to check: (row_change, col_change)
    directions = [(-1, -1), (-1, 0), (-1, 1),  # Up Left, Up, Up Right
                  (0, -1), (0, 1),  # Left, Right
                  (1, -1), (1, 0), (1, 1)]  # Down Left, Down, Down Right

    for dr, dc in directions:
        new_row, new_col = row + dr, col + dc

        # Check if new_row and new_col are within the bounds of the list
        if 0 <= new_row < len(list_of_lists) and 0 <= new_col < len(list_of_lists[0]):
            adjacent_char = list_of_lists[new_row][new_col]
            # Check if the adjacent character is a '*'
            if adjacent_char == "*":
                # Return True and the coordinates of the adjacent symbol
                return True, (new_row, new_col)

    return False, None


def find_valid_numbers(list_of_lists: list) -> int:
    """
    Find all valid numbers in the list of lists.
    :param list_of_lists:
    :return:
    """
    sum_of_partnumbers = 0
    numbers_with_symbols = []

    # Iterate over the list of lists
    for idl, lst in enumerate(list_of_lists):
        idc = 0
        while idc < len(lst):
            char = lst[idc]
            if char.isdigit():
                # Identify the full number
                number = char
                number_end_index = idc
                # Check if the next character is a digit to get the full number
                while number_end_index + 1 < len(lst) and lst[number_end_index + 1].isdigit():
                    number_end_index += 1
                    number += lst[number_end_index]

                # Check if the number is adjacent to a symbol
                for idx in range(idc, number_end_index + 1):
                    isIt, coords = is_adjacent_to_symbol(list_of_lists, idl, idx)
                    if isIt:
                        numbers_with_symbols.append((number, coords))
                        break

                # Update idc to skip the processed part of the number
                idc = number_end_index + 1
            else:
                idc += 1

    # Sort the list of numbers with symbols by the coordinates of the symbols
    numbers_with_symbols.sort(key=lambda x: x[1])

    # Iterate over the list of numbers with symbols
    for i in range(len(numbers_with_symbols) - 1):
        # Check if the symbols are the same for the current and the next number
        if numbers_with_symbols[i][1] == numbers_with_symbols[i + 1][1]:
            # Add the product of the two numbers to the sum
            gear_ratio = int(int(numbers_with_symbols[i][0]) * int(numbers_with_symbols[i + 1][0]))
            print(f"Found a gear ratio of {gear_ratio}, numbers were {int(numbers_with_symbols[i][0])}, {int(numbers_with_symbols[i + 1][0])}")
            sum_of_partnumbers += int(int(numbers_with_symbols[i][0]) * int(numbers_with_symbols[i + 1][0]))

    return sum_of_partnumbers



# Get the list of strings from the file
list_of_strings = file_to_list("adventofcode.com_2023_day_3_input.txt")

# Convert the list of strings to a list of lists
list_of_lists = list_of_strings_to_list_of_lists(list_of_strings)

# Find the valid numbers
valid_numbers = find_valid_numbers(list_of_lists)

# Print the result
print(f"The sum of the valid numbers is {valid_numbers}.")

# %%
2083412
2161828 -> 71407702 # too low
           73698274

           73646890
# Out:
# '.'

# %%
print(len(np.where(content_array == '*')[0]))
# Out:
# 372
