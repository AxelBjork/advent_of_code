# %% [markdown]
# # Day 11: [Title]
#
# [Problem Description](https://adventofcode.com/2025/day/11)

# %%
import sys
from pathlib import Path
sys.path.append(str(Path(__file__).parent.parent))
from utils.inputs import read_lines, read_text

# input_data = read_lines(11)

# %% [markdown]
# ## Part 1

# %% [markdown]
# ## Part 2
